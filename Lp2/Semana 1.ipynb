# %% [markdown]
# <table style="background-color: #f0f0f0; padding: 10px; width: auto;">
# <tr>
# <td style="background-color: #ffffff; vertical-align: middle;"><img src="https://th.bing.com/th/id/OIP.zZshkvEYWRVv1orlaBMmjwHaHa?w=155&h=180&c=7&r=0&o=5&pid=1.7" alt="Logo" style="width: 150px;"/></td>
# <td style="text-align: left; vertical-align: middle; padding-left: 10px;">
# <h2 style="color: #2c3e50; margin: 5;">UNIVERSIDAD NACIONAL AGRARIA LA MOLINA</h2>
# <h3 style="color: #2c3e50; margin: 5;">FACULTAD DE ECONOMÍA Y PLANIFICACIÓN</h3>
# <h5 style="color: #2c3e50; margin: 5;">DEPARTAMENTO DE ESTADÍSTICA E INFORMÁTICA</h5>
# </td>
# </tr>
# </table>

# %% [markdown]
# # **✨ Clase Práctica: Introducción a Jupyter y Python ✨**
#
# **🎯 Objetivo:**
# Al final de esta clase, los estudiantes serán capaces de usar Python en el entorno de Jupyter Notebook, entendiendo los conceptos básicos de la programación estructurada y orientada a objetos, así como las funcionalidades de Markdown y LaTeX para generar reportes técnicos.
#
# ---
#
# ## **🌟 1. Introducción a Jupyter Notebook**
#
# ### **1.1 ¿Qué es Jupyter Notebook?**
# <center><img src="https://jupyter.org/assets/homepage/main-logo.svg" alt="Jupyter Logo" style="width:200px;"/></center>
#
# - Jupyter Notebook es una herramienta interactiva que combina código, texto, visualizaciones y ecuaciones en un solo documento.
# - Es ampliamente utilizado en ciencia de datos, investigación, y educación.
#
# ### **1.2 Estructura Básica de un Notebook**
# - **Celdas de código:** Para escribir y ejecutar código Python.
# - **Celdas de texto (Markdown):** Para descripciones, explicaciones y ecuaciones.
# - **Comandos esenciales:**
#     - `Shift + Enter` para ejecutar celdas.
#     - `Esc + M` para cambiar a celda Markdown.
#
# ---
#
# ## **📝 2. Markdown y LaTeX en Jupyter**
#
# ### **2.1 ¿Qué es Markdown?**
# Markdown es un lenguaje de marcado ligero que facilita el formateo de texto de manera sencilla y elegante.
#
# ### **2.2 Principales Comandos Markdown**
# - **Encabezados:** `# Título 1`, `## Título 2`, etc. (hasta 6 #)
# - **Listas:**
#     - `*`, `-` o `+` para listas desordenadas.
#     - `1.`, `2.` para listas ordenadas.
# - **Enlaces e imágenes:** `[Texto](url)` para enlaces, `![Alt](url)` para imágenes.
#
# ### **2.3 Uso de LaTeX para Matemáticas**
# LaTeX es ideal para escribir ecuaciones matemáticas. Ejemplos:
#
# - **Ecuaciones en línea:** `$E = mc^2$`.
# - **Ecuaciones centradas:** `$$ E = mc^2 $$`.
#
# Ejemplo de una ecuación más compleja:
#
# $$
# \int_{a}^{b} x^2 \,dx
# $$
#
# **Pasemos a los archivos:**
#   - Primera Práctica Dirigida_Markdown_20241.ipynb
#   - Segunda_Práctica_Dirigida_Markdown_LaTex_20241.ipynb
#
#
# **🛠 Actividad 1:**
# Crear una celda Markdown con un título, una lista de pasos y una ecuación usando LaTeX.
#
# ---

# %% [markdown]
# ## **🔧 3. Librerías de Python en Jupyter**
#
# ### **3.1 Importación de Librerías Comunes**
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Configuración de estilo para gráficos
# plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### **3.2 Ejemplos Prácticos**

# %% [markdown]
# 🔢 **Numpy:** Crear un array y realizar operaciones básicas

# %%
import numpy as np
array = np.array([1, 2, 3, 4, 5])
print("📊 Array:", array)
print("🔢 Suma de todos los elementos:", np.sum(array))
# Out:
# 📊 Array: [1 2 3 4 5]
# 🔢 Suma de todos los elementos: 15

# %% [markdown]
# 📊 **Pandas:** Leer un archivo CSV y mostrar el primer conjunto de datos

# %%
import pandas as pd
# Si tienes un archivo CSV
# df = pd.read_csv('archivo.csv')
# Si no tienes un CSV, puedes crear un DataFrame de ejemplo
data = {'Nombre': ['Ana', 'Luis', 'Pedro'], 'Edad': [23, 25, 22]}
df = pd.DataFrame(data)
df.head()
# Out:
#   Nombre  Edad
# 0    Ana    23
# 1   Luis    25
# 2  Pedro    22

# %% [markdown]
# 📈 **Matplotlib & Seaborn:** Crear un gráfico con estilo

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label='Seno de x', color='purple', linewidth=2)
plt.title("Gráfico de Seno", fontsize=16)
plt.xlabel("x", fontsize=14)
plt.ylabel("sin(x)", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 🛠 **Actividad 2:**
# Utilizar Numpy y Matplotlib para generar una secuencia de números y graficarla con un estilo personalizado.

# %% [markdown]
# ## **📊 4. Creación de Reportes Técnicos**
# ### **4.1 Combinar Código y Texto**
#  - Usa celdas Markdown para describir el análisis.
#  - Incluye gráficos y resultados dentro del notebook.
# 🎨 Tip: Puedes usar celdas de texto con Markdown para organizar tu reporte y agregar elementos visuales como emojis, imágenes, y estilos.
#
# ### **4.2 Exportar Notebooks**
#  - Guardar como .ipynb para continuar trabajando.
#  - Exportar como .html o .pdf para compartir y presentar.
#
# **🛠 Actividad 3:**
# Crear un mini reporte técnico en un notebook que incluya un análisis simple con Pandas y un gráfico con Matplotlib, con secciones de texto explicativo usando Markdown y estilo.
